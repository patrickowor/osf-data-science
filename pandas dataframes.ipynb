# %%
import pandas as pd

# %%
mySeries = pd.Series(["ade", "bola", "sade", 
                      "odion", "john", "mohammed",
                      "sege", "jeni", "lade", 
                      "oriyomi", "lactavius", "lala", ], name="name")

# %%
mySeries
# Out:
# 0           ade
# 1          bola
# 2          sade
# 3         odion
# 4          john
# 5      mohammed
# 6          sege
# 7          jeni
# 8          lade
# 9       oriyomi
# 10    lactavius
# 11         lala
# Name: name, dtype: object

# %%
mySeries.head(5)
# Out:
# 0      ade
# 1     bola
# 2     sade
# 3    odion
# 4     john
# Name: name, dtype: object

# %%
mySeries.tail()
# Out:
# 7          jeni
# 8          lade
# 9       oriyomi
# 10    lactavius
# 11         lala
# Name: name, dtype: object

# %%
mySeries.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 12 entries, 0 to 11
# Series name: name
# Non-Null Count  Dtype
# --------------  -----
# 12 non-null     object
# dtypes: object(1)
# memory usage: 228.0+ bytes

# %%
mySeries2 = pd.Series([10, 20, 40, 25, 2,4, 18, 32, 11, 12, 32, 19], name="age")

# %%
mySeries2
# Out:
# 0     10
# 1     20
# 2     40
# 3     25
# 4      2
# 5      4
# 6     18
# 7     32
# 8     11
# 9     12
# 10    32
# 11    19
# Name: age, dtype: int64

# %%
pd.concat?
# Out:
# Signature:
# pd.concat(
#     objs: 'Iterable[Series | DataFrame] | Mapping[HashableT, Series | DataFrame]',
#     *,
#     axis: 'Axis' = 0,
#     join: 'str' = 'outer',
#     ignore_index: 'bool' = False,
#     keys: 'Iterable[Hashable] | None' = None,
#     levels=None,
#     names: 'list[HashableT] | None' = None,
#     verify_integrity: 'bool' = False,
#     sort: 'bool' = False,
#     copy: 'bool | None' = None,
# ) -> 'DataFrame | Series'
# Docstring:
# Concatenate pandas objects along a particular axis.
#
# Allows optional set logic along the other axes.
#
# Can also add a layer of hierarchical indexing on the concatenation axis,
# which may be useful if the labels are the same (or overlapping) on
# the passed axis number.
#
# Parameters
# ----------
# objs : a sequence or mapping of Series or DataFrame objects
#     If a mapping is passed, the sorted keys will be used as the `keys`
#     argument, unless it is passed, in which case the values will be
# ...

# %% [markdown]
# ### Dataframes

# %%
# dataframes are just a collection of series-es  
df = pd.concat([mySeries, mySeries2],axis=1 )

# %%
df.head()
# Out:
#     name  age
# 0    ade   10
# 1   bola   20
# 2   sade   40
# 3  odion   25
# 4   john    2

# %%
df.tail()
# Out:
#          name  age
# 7        jeni   32
# 8        lade   11
# 9     oriyomi   12
# 10  lactavius   32
# 11       lala   19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    12 non-null     object
#  1   age     12 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 324.0+ bytes

# %%
data = {"school":  ["exquitec", "tasued", "oou"], "rating": ["1001%", "45%", "49%"]}

df2 = pd.DataFrame(data )

# %%
df2
# Out:
#      school rating
# 0  exquitec  1001%
# 1    tasued    45%
# 2       oou    49%

# %%
df2.columns
# Out:
# Index(['school', 'rating'], dtype='object')

# %%
df2.values
# Out:
# array([['exquitec', '1001%'],
#        ['tasued', '45%'],
#        ['oou', '49%']], dtype=object)

# %%
df2.loc[2] # locate a row with index
# Out:
# 'oou'

# %%
df2.loc[[1,2]]# start from index 1 and stop at index 2 same as list[1: 2+ 1]
# Out:
#    school rating
# 1  tasued    45%
# 2     oou    49%

# %%
df2["school"]
# Out:
# 0    exquitec
# 1      tasued
# 2         oou
# Name: school, dtype: object

# %%
df2.school
# Out:
# 0    exquitec
# 1      tasued
# 2         oou
# Name: school, dtype: object

# %%
# we can set indexes same way we did in series
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df3 = pd.DataFrame(data, index = ["day1", "day2", "day3"])
df3
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
df3.loc["day1"]
# Out:
# calories    420
# duration     50
# Name: day1, dtype: int64

# %%
# creating a datfame from csv
df4 = pd.read_csv("./submission.csv")

# %%
df4
# Out:
#      Unnamed: 0  antelope_duiker          bird     blank   civet_genet  \
# 0      ZJ016488     3.826669e-01  2.407341e-05  0.476484  2.112874e-02
# 1      ZJ016489     4.746906e-01  1.496750e-01  0.305126  2.320115e-03
# 2      ZJ016490     6.456634e-01  1.716497e-03  0.142280  1.979082e-01
# 3      ZJ016491     4.118669e-02  3.176303e-04  0.523943  5.102386e-04
# 4      ZJ016492     2.431463e-01  1.123199e-01  0.352065  7.143924e-04
# ...         ...              ...           ...       ...           ...
# 4459   ZJ020947     4.795790e-02  7.627419e-03  0.286607  5.549190e-05
# 4460   ZJ020948     5.873994e-01  3.004222e-02  0.322895  6.307406e-03
# 4461   ZJ020949     8.793562e-02  3.861581e-04  0.357812  4.791451e-01
# 4462   ZJ020950     1.816390e-03  7.773371e-04  0.032405  2.546880e-07
# 4463   ZJ020951     1.712096e-07  2.328019e-08  0.000024  3.469024e-11
#
#                hog   leopard  monkey_prosimian        rodent
# ...

# %%
df4.head()
# Out:
#   Unnamed: 0  antelope_duiker      bird     blank  civet_genet       hog  \
# 0   ZJ016488         0.382667  0.000024  0.476484     0.021129  0.000013
# 1   ZJ016489         0.474691  0.149675  0.305126     0.002320  0.001275
# 2   ZJ016490         0.645663  0.001716  0.142280     0.197908  0.001073
# 3   ZJ016491         0.041187  0.000318  0.523943     0.000510  0.001445
# 4   ZJ016492         0.243146  0.112320  0.352065     0.000714  0.000588
#
#     leopard  monkey_prosimian    rodent
# 0  0.000952          0.001920  0.116811
# 1  0.019998          0.032596  0.014319
# 2  0.002253          0.001272  0.007834
# 3  0.426141          0.006115  0.000341
# 4  0.242248          0.044126  0.004792

# %%
df4.tail()
# Out:
#      Unnamed: 0  antelope_duiker          bird     blank   civet_genet  \
# 4459   ZJ020947     4.795790e-02  7.627419e-03  0.286607  5.549190e-05
# 4460   ZJ020948     5.873994e-01  3.004222e-02  0.322895  6.307406e-03
# 4461   ZJ020949     8.793562e-02  3.861581e-04  0.357812  4.791451e-01
# 4462   ZJ020950     1.816390e-03  7.773371e-04  0.032405  2.546880e-07
# 4463   ZJ020951     1.712096e-07  2.328019e-08  0.000024  3.469024e-11
#
#                hog   leopard  monkey_prosimian        rodent
# 4459  3.099524e-03  0.008848      6.456940e-01  1.104130e-04
# 4460  6.658868e-03  0.009276      2.869093e-02  8.729522e-03
# 4461  2.266362e-03  0.035645      1.221466e-03  3.558840e-02
# 4462  2.365757e-08  0.963268      1.726992e-03  5.265934e-06
# 4463  2.346670e-09  0.999975      6.254680e-07  8.280294e-10

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4464 entries, 0 to 4463
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        4464 non-null   object
#  1   antelope_duiker   4464 non-null   float64
#  2   bird              4464 non-null   float64
#  3   blank             4464 non-null   float64
#  4   civet_genet       4464 non-null   float64
#  5   hog               4464 non-null   float64
#  6   leopard           4464 non-null   float64
#  7   monkey_prosimian  4464 non-null   float64
#  8   rodent            4464 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 314.0+ KB

# %%
df4.columns
# Out:
# Index(['Unnamed: 0', 'antelope_duiker', 'bird', 'blank', 'civet_genet', 'hog',
#        'leopard', 'monkey_prosimian', 'rodent'],
#       dtype='object')

# %%
df4.Index = df4["Unnamed: 0"]
# Out:
# C:\Users\SourceBird\AppData\Local\Temp\ipykernel_11568\3898358618.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df4.Index = df4["Unnamed: 0"]

# %%
df6 = df4.set_index(df4["Unnamed: 0"].values) # set an index

# %%
df4
# Out:
#      Unnamed: 0  antelope_duiker          bird     blank   civet_genet  \
# 0      ZJ016488     3.826669e-01  2.407341e-05  0.476484  2.112874e-02
# 1      ZJ016489     4.746906e-01  1.496750e-01  0.305126  2.320115e-03
# 2      ZJ016490     6.456634e-01  1.716497e-03  0.142280  1.979082e-01
# 3      ZJ016491     4.118669e-02  3.176303e-04  0.523943  5.102386e-04
# 4      ZJ016492     2.431463e-01  1.123199e-01  0.352065  7.143924e-04
# ...         ...              ...           ...       ...           ...
# 4459   ZJ020947     4.795790e-02  7.627419e-03  0.286607  5.549190e-05
# 4460   ZJ020948     5.873994e-01  3.004222e-02  0.322895  6.307406e-03
# 4461   ZJ020949     8.793562e-02  3.861581e-04  0.357812  4.791451e-01
# 4462   ZJ020950     1.816390e-03  7.773371e-04  0.032405  2.546880e-07
# 4463   ZJ020951     1.712096e-07  2.328019e-08  0.000024  3.469024e-11
#
#                hog   leopard  monkey_prosimian        rodent
# ...

# %%
# we can set index when reading the csv 
df5 = pd.read_csv("./submission.csv", index_col="Unnamed: 0") 
df5.head()
# Out:
#           antelope_duiker      bird     blank  civet_genet       hog  \
# ZJ016488         0.382667  0.000024  0.476484     0.021129  0.000013
# ZJ016489         0.474691  0.149675  0.305126     0.002320  0.001275
# ZJ016490         0.645663  0.001716  0.142280     0.197908  0.001073
# ZJ016491         0.041187  0.000318  0.523943     0.000510  0.001445
# ZJ016492         0.243146  0.112320  0.352065     0.000714  0.000588
#
#            leopard  monkey_prosimian    rodent
# ZJ016488  0.000952          0.001920  0.116811
# ZJ016489  0.019998          0.032596  0.014319
# ZJ016490  0.002253          0.001272  0.007834
# ZJ016491  0.426141          0.006115  0.000341
# ZJ016492  0.242248          0.044126  0.004792

# %%
df6.head()
# Out:
#          Unnamed: 0  antelope_duiker      bird     blank  civet_genet  \
# ZJ016488   ZJ016488         0.382667  0.000024  0.476484     0.021129
# ZJ016489   ZJ016489         0.474691  0.149675  0.305126     0.002320
# ZJ016490   ZJ016490         0.645663  0.001716  0.142280     0.197908
# ZJ016491   ZJ016491         0.041187  0.000318  0.523943     0.000510
# ZJ016492   ZJ016492         0.243146  0.112320  0.352065     0.000714
#
#                hog   leopard  monkey_prosimian    rodent
# ZJ016488  0.000013  0.000952          0.001920  0.116811
# ZJ016489  0.001275  0.019998          0.032596  0.014319
# ZJ016490  0.001073  0.002253          0.001272  0.007834
# ZJ016491  0.001445  0.426141          0.006115  0.000341
# ZJ016492  0.000588  0.242248          0.044126  0.004792

# %%
df6 = df6.drop(["Unnamed: 0"], axis=1)

# %%
df6
# Out:
#           antelope_duiker          bird     blank   civet_genet           hog  \
# ZJ016488     3.826669e-01  2.407341e-05  0.476484  2.112874e-02  1.290608e-05
# ZJ016489     4.746906e-01  1.496750e-01  0.305126  2.320115e-03  1.275096e-03
# ZJ016490     6.456634e-01  1.716497e-03  0.142280  1.979082e-01  1.072702e-03
# ZJ016491     4.118669e-02  3.176303e-04  0.523943  5.102386e-04  1.445462e-03
# ZJ016492     2.431463e-01  1.123199e-01  0.352065  7.143924e-04  5.878492e-04
# ...                   ...           ...       ...           ...           ...
# ZJ020947     4.795790e-02  7.627419e-03  0.286607  5.549190e-05  3.099524e-03
# ZJ020948     5.873994e-01  3.004222e-02  0.322895  6.307406e-03  6.658868e-03
# ZJ020949     8.793562e-02  3.861581e-04  0.357812  4.791451e-01  2.266362e-03
# ZJ020950     1.816390e-03  7.773371e-04  0.032405  2.546880e-07  2.365757e-08
# ZJ020951     1.712096e-07  2.328019e-08  0.000024  3.469024e-11  2.346670e-09
#
# ...

# %%
smallerdf = df6[["bird", "hog", "blank"]]

# %%
# creating a smaller df with 100 rows and 3 columns
mynewIndex = []
for i in list(smallerdf.index):
    if i == "ZJ016588":
        break
    mynewIndex.append(i)
smallerdf.loc[mynewIndex]
# Out:
#                   bird           hog     blank
# ZJ016488  2.407341e-05  1.290608e-05  0.476484
# ZJ016489  1.496750e-01  1.275096e-03  0.305126
# ZJ016490  1.716497e-03  1.072702e-03  0.142280
# ZJ016491  3.176303e-04  1.445462e-03  0.523943
# ZJ016492  1.123199e-01  5.878492e-04  0.352065
# ...                ...           ...       ...
# ZJ016583  5.198195e-02  8.837816e-06  0.500005
# ZJ016584  1.041752e-05  9.654539e-08  0.055900
# ZJ016585  1.580568e-08  6.088030e-04  0.004719
# ZJ016586  6.515752e-05  3.211814e-05  0.034586
# ZJ016587  3.870420e-03  3.187476e-03  0.949300
#
# [100 rows x 3 columns]

# %%
df7 = pd.read_json("sample.json")

# %%
df7
# Out:
#    names  age student_class
# 0    ade   25          100l
# 1  segun   22          200l
# 2  nonye   23          300l

# %%
df7.to_csv("sample.csv")
