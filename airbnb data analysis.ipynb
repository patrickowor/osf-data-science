# %%
import pandas as pd

# %%
df = pd.read_csv("airbnb.csv")
df.head()
# Out:
#                              id_visitor                        id_session  \
# 0  ed1329a6-064d-47e9-93bc-93f5a50822df  a8dfb8ed5aa79e00ff14b2da297c9778
# 1  ed1329a6-064d-47e9-93bc-93f5a50822df  950277daef16f86dc2c05d2b212eea81
# 2  ed1329a6-064d-47e9-93bc-93f5a50822df  ee4e2f99dd0c0bef2d40e4bdf880c862
# 3  ed1329a6-064d-47e9-93bc-93f5a50822df  59fbde7b5d35403116c461fa7fc1ab6e
# 4  ed1329a6-064d-47e9-93bc-93f5a50822df  ec8972a3c7256ea4dcba61ee2bd9e3a8
#
#    dim_session_number                                     dim_user_agent  \
# 0                  83                            Airbnb/6.0 iPhone/8.1.2
# 1                  84  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 2                  85  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 3                  86  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 4                  87  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
#
#   dim_device_app_combo          ds               ts_min               ts_max  \
# ...

# %%
df.tail(3)
# Out:
#                        id_visitor                        id_session  \
# 7753  1414271365_EuFmeZ+vsDuryP8F  e7ce67245dc553d51673d33e7b1a53a7
# 7754  1414271365_EuFmeZ+vsDuryP8F  472d2822a2707b384d27ec510594dcee
# 7755  1416012256_dB6ft6mhjVRXX48c  38f19c985529fc64f8759f614632731d
#
#       dim_session_number                                     dim_user_agent  \
# 7753                   5  Mozilla/5.0 (iPad; CPU OS 7_1_2 like Mac OS X)...
# 7754                   6  Mozilla/5.0 (iPad; CPU OS 7_1_2 like Mac OS X)...
# 7755                   1  Mozilla/5.0 (Windows NT 6.2; Win64; x64) Apple...
#
#      dim_device_app_combo          ds               ts_min  \
# 7753           iPad - Web  2015-02-16  2015-02-16 02:48:38
# 7754           iPad - Web  2015-03-11  2015-03-11 10:33:52
# 7755     Desktop - Chrome  2014-10-25  2014-10-25 00:44:17
#
#                    ts_max  did_search  sent_message  ...  \
# 7753  2015-02-16 02:59:20           1             0  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7756 entries, 0 to 7755
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id_visitor                 7756 non-null   object
#  1   id_session                 7756 non-null   object
#  2   dim_session_number         7756 non-null   int64
#  3   dim_user_agent             7537 non-null   object
#  4   dim_device_app_combo       7756 non-null   object
#  5   ds                         7756 non-null   object
#  6   ts_min                     7756 non-null   object
#  7   ts_max                     7756 non-null   object
#  8   did_search                 7756 non-null   int64
#  9   sent_message               7756 non-null   int64
#  10  sent_booking_request       7756 non-null   int64
#  11  next_id_session            7126 non-null   object
#  12  next_dim_session_number    7126 non-null   float64
# ...

# %%
mean_of_next_dim_session_number = df['next_dim_session_number'].mean()

# %%
 df['next_dim_session_number'].fillna(mean_of_next_dim_session_number, inplace=True, )
# Out:
# C:\Users\SourceBird\AppData\Local\Temp\ipykernel_21556\3548197389.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['next_dim_session_number'].fillna(mean_of_next_dim_session_number, inplace=True, )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7756 entries, 0 to 7755
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id_visitor                 7756 non-null   object
#  1   id_session                 7756 non-null   object
#  2   dim_session_number         7756 non-null   int64
#  3   dim_user_agent             7537 non-null   object
#  4   dim_device_app_combo       7756 non-null   object
#  5   ds                         7756 non-null   object
#  6   ts_min                     7756 non-null   object
#  7   ts_max                     7756 non-null   object
#  8   did_search                 7756 non-null   int64
#  9   sent_message               7756 non-null   int64
#  10  sent_booking_request       7756 non-null   int64
#  11  next_id_session            7126 non-null   object
#  12  next_dim_session_number    7756 non-null   float64
# ...

# %%
df = df.dropna(ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6781 entries, 0 to 6780
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id_visitor                 6781 non-null   object
#  1   id_session                 6781 non-null   object
#  2   dim_session_number         6781 non-null   int64
#  3   dim_user_agent             6781 non-null   object
#  4   dim_device_app_combo       6781 non-null   object
#  5   ds                         6781 non-null   object
#  6   ts_min                     6781 non-null   object
#  7   ts_max                     6781 non-null   object
#  8   did_search                 6781 non-null   int64
#  9   sent_message               6781 non-null   int64
#  10  sent_booking_request       6781 non-null   int64
#  11  next_id_session            6781 non-null   object
#  12  next_dim_session_number    6781 non-null   float64
# ...

# %%
df.head(2)
# Out:
#                              id_visitor                        id_session  \
# 0  ed1329a6-064d-47e9-93bc-93f5a50822df  a8dfb8ed5aa79e00ff14b2da297c9778
# 1  ed1329a6-064d-47e9-93bc-93f5a50822df  950277daef16f86dc2c05d2b212eea81
#
#    dim_session_number                                     dim_user_agent  \
# 0                  83                            Airbnb/6.0 iPhone/8.1.2
# 1                  84  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
#
#   dim_device_app_combo          ds               ts_min               ts_max  \
# 0         iPhone - iOS  2015-02-16  2015-02-16 21:50:41  2015-02-16 22:13:42
# 1     Desktop - Chrome  2015-02-18  2015-02-18 11:57:15  2015-02-18 12:12:48
#
#    did_search  sent_message  ...                   next_id_session  \
# 0           0             0  ...  b812bf56bf89b0b31f4e5b50d0c15ff8
# 1           0             0  ...  456083b5f5506ad125d595006819de1d
#
#   next_dim_session_number                                next_dim_user_agent  \
# ...

# %%
iphone_df_list = []
for i, value in  enumerate(df["dim_device_app_combo"].values):
    if value.strip().lower() == "iPhone - iOS".lower():
        iphone_df_list.append(df.loc[i])

# %%
iphone_df_list[-1]
# Out:
# id_visitor                   0efe4fb3877e9ff12a05fa4ffe1a9531ff5143ea
# id_session                           ae60fb6fff20362fdc9856949ccbef05
# dim_session_number                                                  2
# dim_user_agent                                Airbnb/3.5.1 iPhone/7.1
# dim_device_app_combo                                     iPhone - iOS
# ds                                                         2014-07-24
# ts_min                                            2014-07-24 21:49:01
# ts_max                                            2014-07-24 22:04:57
# did_search                                                          0
# sent_message                                                        0
# sent_booking_request                                                0
# next_id_session                      42b99c51e4fce3db977c9a1b6e9936ad
# next_dim_session_number                                           3.0
# ...

# %%
iphone_df = pd.concat(iphone_df_list, axis=1)
iphone_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, id_visitor to next_sent_booking_request
# Columns: 2034 entries, 0 to 6743
# dtypes: object(2034)
# memory usage: 334.4+ KB

# %%
iphone_df.head()
# Out:
#                                                       0     \
# id_visitor            ed1329a6-064d-47e9-93bc-93f5a50822df
# id_session                a8dfb8ed5aa79e00ff14b2da297c9778
# dim_session_number                                      83
# dim_user_agent                     Airbnb/6.0 iPhone/8.1.2
# dim_device_app_combo                          iPhone - iOS
#
#                                                       16    \
# id_visitor            ed1329a6-064d-47e9-93bc-93f5a50822df
# id_session                e5eaf6ed7205ff92f2a2ce3e8706230d
# dim_session_number                                      11
# dim_user_agent                   Airbnb/3.3.1 iPhone/8.1.2
# dim_device_app_combo                          iPhone - iOS
#
#                                                       17    \
# id_visitor            ed1329a6-064d-47e9-93bc-93f5a50822df
# id_session                02a335df52433dccad176a8cfa08b49c
# dim_session_number                                      12
# ...

# %%
iphone_df2= iphone_df.transpose()

# %%
iphone_df2.head()
# Out:
#                               id_visitor                        id_session  \
# 0   ed1329a6-064d-47e9-93bc-93f5a50822df  a8dfb8ed5aa79e00ff14b2da297c9778
# 16  ed1329a6-064d-47e9-93bc-93f5a50822df  e5eaf6ed7205ff92f2a2ce3e8706230d
# 17  ed1329a6-064d-47e9-93bc-93f5a50822df  02a335df52433dccad176a8cfa08b49c
# 19  ed1329a6-064d-47e9-93bc-93f5a50822df  ebbfb835927bdc66a51c49dbfca188cb
# 31  ed1329a6-064d-47e9-93bc-93f5a50822df  d28dba3d0922222709cbd74fec2c3575
#
#    dim_session_number             dim_user_agent dim_device_app_combo  \
# 0                  83    Airbnb/6.0 iPhone/8.1.2         iPhone - iOS
# 16                 11  Airbnb/3.3.1 iPhone/8.1.2         iPhone - iOS
# 17                 12  Airbnb/4.7.0 iPhone/8.1.2         iPhone - iOS
# 19                 14  Airbnb/4.7.0 iPhone/8.1.2         iPhone - iOS
# 31                 26  Airbnb/4.7.0 iPhone/8.1.2         iPhone - iOS
#
#             ds               ts_min               ts_max did_search  \
# ...

# %%
df["mynew col"] = []
